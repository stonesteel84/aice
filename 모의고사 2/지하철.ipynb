# %% [markdown]
# # AICE Associate 연습문제
#
#
# ## 지하철 이용객 수 예측
#
# 지하철 이용객에 대한 데이터를 읽어들여 데이터를 분석 및 전처리한 후 머신러닝과 딥러닝으로 지하철 이용객 수를 예측하고 결과를 분석하세요.

# %% [markdown]
# 1. pandas 라이브러리를 별칭 pd로 임포트하는 코드를 작성하고 실행하시오.
# 설치되어 있지 않으면 설치해서 임포트 하시오.

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# 2. 모델링을 위해 분석 및 처리할 데이터 파일을 읽어오려고 합니다.
# 아래 요구사항에 맞추어 pandas 함수로 데이터 파일을 불러오세요.
#
# - Metro_Traffic_Volume_Data.csv 파일을 읽어 df_a에 할당하세요.
# - Days_Information_Data.csv 파일을 읽어 df_b에 할당하세요.
# - 두 데이터프레임은 중복값을 가지고 있습니다. 중복된 행을 삭제하세요.
#     - duplicated() 또는 drop_duplicates()를 사용하세요.
#     - 답안02 변수에 각 데이터프레임의 중복값의 총합를 저장하세요.
# - df_a와 df_b 데이터프레임을 판다스의 merge 함수를 활용하여 합쳐 데이터프레임 변수명 df에 저장하세요.
#     - 합칠 때 사용하는 키(on) : 'date_time'
#     - 합치는 방법(how) : 'inner'

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# 3. "holiday"의 분포도를 알아보려고 합니다.
#
# holiday에 대해 countplot그래프로 만드는 코드와 답안을 작성하세요.
# - Seaborn을 활용하세요.
# - value_counts()를 사용하여 더 자세한 내용을 확인하세요.
#
# 출력된 그래프와 통계를 보고 해석한 것으로 옳지 않은 선택지를 아래에서 골라 "답안03" 변수에 저장하세요(예: 답안03=1)
#
# 1. "holiday" 컬럼에는 총 13개의 유니크 값이 있다.
# 2. 휴일이 아닌 날은 40000일이 넘는다.
# 3. 휴일의 총합은 1409개이다.

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# 4. 위의 "holiday"의 분포도를 보면 "None"의 수가 압도적인 것을 발견할 수 있습니다.
#
# 가이드에 따라서 전처리를 수행하고 저장하세요.
# - 원본을 보관하기 위해 df_temp에 df를 복사하여 저장하세요.
#     - 대상 데이터프레임 : df_temp
#     - "holiday"의 값이 "None"인 경우에 N, 그 외인 경우에 Y로 채워진 "is_holiday"라는 컬럼을 추가하세요.
#     - 불필요한 'holiday' 컬럼을 삭제 하세요.
#     - 전처리 반영 후에 새로운 데이터프레임 변수명 df_temp 에 저장하세요.

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# 다음 문항을 풀기 전에 아래 코드를 실행하세요.

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
plt.rc("font", family="NanumGothicCoding")

# %% [markdown]
# 5. "traffic_volume"의 상관관계를 확인하세요.
#
# - seaborn을 사용하세요
# - "traffic_volume"과 가장 상관관계가 높은 feature를 답안05에 저장하세요.

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# 6. 모델링 성능을 제대로 얻기 위해서 불필요한 변수 처리는 필수입니다.
#
# 아래 가이드를 따라 결측치 처리하세요.
# - 대상 데이터프레임 : df_temp
# - "Unnamed: 0", "date_time", "weather_description" 3개 컬럼을 제거합니다.
# - 전처리 반영된 결과를 새로운 데이터프레임 변수명 `df_del` 에 저장하세요.

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# 7. 모델링 성능을 제대로 얻기 위해서 불필요한 변수와 결측치 처리는 필수입니다.
#
# 아래 가이드를 따라 결측치 처리하세요.
# - 대상 데이터프레임 : df_del
# - 결측치를 확인하는 코드를 작성하세요.
# - 결측치가 있는 행(row)를 삭제 하세요.
# - 전처리 반영된 결과를 새로운 데이터프레임 변수명 df_na 에 저장하세요.
# - 결측치 개수를 '답안07 변수에 저장하세요.(예. 답안07= 5)

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# 8. 원-핫 인코딩(One-hot encoding)은 범주형 변수를 1과 0의 이진형 벡터로 변환하기 위하여 사용하는 방법입니다.
#
# 원-핫 인코딩으로 아래 조건에 해당하는 컬럼 데이터를 변환하세요.
#
#  - 대상 데이터프레임: df_na
#  - 원-핫 인코딩 대상: object 타입의 전체 컬럼
#  - 활용 함수: Pandas의 get_dummies
#  - 해당 전처리가 반영된 결과를 데이터프레임 변수 df_preset에 저장해 주세요.

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# 9. 훈련과 검증 각각에 사용할 데이터셋을 분리하려고 합니다.
# traffic_volume 컬럼을 y로, 나머지 컬럼을 feature값 X로 할당한 후, 훈련데이터셋과 검증데이터셋으로 분리하세요.
#
# 추가로 가이드 따라서 훈련데이터셋과 검증데이터셋에 스케일링을 수행하세요.
#
#  - 대상 데이터프레임: df_preset
#  - 훈련과 검증 데이터셋 분리
#      - 훈련 데이터셋 label: y_train, 훈련 데이터셋 Feature: X_train
#      - 검증 데이터셋 label: y_valid, 검증 데이터셋 Feature: X_valid
#      - 훈련 데이터셋과 검증데이터셋의 비율은 80:20
#      - random_state: 42
#      - Scikit-learn의 train_test_split 함수를 활용하세요
#  - MinMaxScaler 스케일링 수행
#      - 대상 컬럼: "temp", "clouds_all"
#      - sklearn.preprocessing의 MinMaxScaler함수 사용
#      - 훈련데이터셋의 Feature는 MinMaxScaler의 fit_transform 함수를 활용하여 X_train 변수로 할당
#      - 검증데이터셋의 Feature는 MinMaxScaler의 transform 함수를 활용하여 X_valid 변수로 할당
#  - StandardScaler 스케일링 수행
#      - 대상 컬럼: MinMaxScaler를 적용하지 않은 모든 컬럼
#      - sklearn.preprocessing의 StandardScaler함수 사용
#      - 훈련데이터셋의 Feature는 StandardScaler의 fit_transform 함수를 활용하여 X_train 변수로 할당
#      - 검증데이터셋의 Feature는 StandardScaler의 transform 함수를 활용하여 X_valid 변수로 할당

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# 10. traffic_volume을 예측하는 머신러닝 모델을 만들려고 합니다.
#
# 아래 가이드에 따라 다양한 모델을 학습하세요 (fit 사용)
#
# - 구현 모델
#     - 선형 모델 : LinearRegression
#     - 트리기반 앙상블 모델 (배깅 기법) : RandomForestRegressor, GradientBoostingRegressor
#     - 트리기반 앙상블 모델 (부스팅 기법) : XGBRegressor
# - 아래 옵션이 있는 모델은 옵션값을 적용하세요.
#     - random_state : 42
#     - n_jobs : -1

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# 11. 위에서 구현한 다양한 모델의 성능을 평가하려고 합니다.
# 아래 가이드에 따라 예측 결과의 R2_score와 rmse(Root Mean Squere Error)를 구하고 평가하세요.
# - 성능 평가는 검증 데이터셋을 활용하세요.
# - sklearn.metrics의 r2_score와 mean_squared_error를 이용하세요
#
# - 설명력이 가장 좋은 성능을 보인 모델 이름을 '답안11' 변수에 저장하세요.
#     - 예) 답안11='LinearRegression' 혹은 답안11='GradientBoostingRegressor'

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# 다음 문항을 풀기 전에 아래 코드를 실행하세요.

# %%
import random
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import to_categorical

random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)
tf.keras.utils.set_random_seed(42)

# %% [markdown]
# 12. traffic_volume을 예측하는 딥러닝 모델을 만들려고 합니다.
# 아래 가이드에 따라 모델링하고 학습을 진행하세요.
# - Tensorflow framework를 사용하여 딥러닝 모델을 만드세요.
# - 아래의 설계된 모델을 구현하세요.
# - 손실함수는 'mse'를 사용하고, 손실함수를 최적화하기 위한 알고리즘은 'adam'을 사용하세요.
# - 각 에포크마다 검증데이터셋을 'mae'와 'mse'로 평가하세요.
# - 하이퍼파라미터 epochs : 30, batch_size : 16 로 설정해 주세요.
# - 각 에포크마다 loss와 metrics 평가하기 위한 데이터로 X_valid, y_valid 사용하세요.
# - 학습정보는 history 변수에 저장해 주세요.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# 13. Matplotlib 라이브러리 활용해서 학습 mae와 검증 mae를 그래프로 표시하세요.
# - 1개의 그래프에 학습 mae와 검증 mae 2가지를 모두 표시하세요.
# - 위 2가지 각각의 범례를 'mae', 'val_mae'로 표시하세요.
# - 그래프의 타이틀은 'Model MAE'로 표시하세요.
# - X축에는 'Epochs'라고 표시하고 Y축에는 'MAE'라고 표시하세요.

# %%
# 여기에 답안코드를 작성하세요.
