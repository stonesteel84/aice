# %% [markdown]
# # AICE Associate 연습문제

# %% [markdown]
# ## 은행 고객이탈(Customer Churn Prediction)
#
# 은행 고객이탈 데이터를 읽어들여 데이터를 분석 및 전처리한 후 머신러닝과 딥러닝으로 은행 고객이탈 여부를 예측하고 결과를 분석하세요.
#
# ---
# RowNumber: 데이터셋의 각 행에 부여된 순번<br>
# CustomerId: 고객 고유 식별자<br>
# Surname: 고객의 성<br>
# CreditScore: 신용 점수<br>
# Geography: 고객의 거주 지역(예: France, Spain, Germany)<br>
# Gender: 성별<br>
# Age: 나이<br>
# Tenure: 은행 거래 연수<br>
# Balance: 계좌 잔액<br>
# NumOfProducts: 보유한 은행 상품 수<br>
# HasCrCard: 신용카드 보유 여부<br>
# IsActiveMember: 활동 회원 여부<br>
# EstimatedSalary: 추정 연봉<br>
# Exited: 고객 이탈 여부(0: 이탈하지 않음, 1: 이탈함)<br>
#
# ---

# %% [markdown]
# ### 1. pandas 라이브러리를 별칭 pd로 임포트하는 코드를 작성하고 실행하세요.
# ---
# - 설치되어 있지 않으면 설치해서 임포트하세요.
# ---

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# <br>

# %% [markdown]
# 다음 문항을 풀기 전에 아래의 코드를 실행하세요.

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
plt.rc("font", family="NanumGothicCoding")

# %% [markdown]
# <br>

# %% [markdown]
# ### 2. 모델링을 위해 분석 및 처리할 데이터 파일을 읽어오려고 합니다.
# ---
# pandas 함수로 데이터 파일을 읽고 데이터프레임 변수명 df에 할당하는 코드를 작성하세요.
# - Churn_Modelling_nan.csv 파일을 읽어 변수명 df에 할당하세요.
# ---

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# <br>

# %% [markdown]
# ### 3. 합쳐진 데이터프레임을 살펴보려고 합니다.
# ---
# 데이터프레임을 요약 및 기초통계기법으로 확인하는 코드를 작성하세요.
# - 출력된 데이터프레임의 정보와 일치하지 않는 내용을 '답안03'변수에 저장하세요. (예: 답안03=1)
#     1. 데이터의 총 컬럼 수는 13개 이다.
#     2. Surname에는 총 2931개의 고유한 값이 존재한다.
#     3. 나이의 평균값은 약 39세이다.
#     4. CreditScore의 표준편차는 약 96.65이다.
# ---

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# <br>

# %% [markdown]
# ### 4. 고객 이탈 여부(Exited)에 따른 지역(Geography)의 분포를 확인하려고 합니다.
# ---
# Geography에 대해 countplot그래프로 만드는 코드와 답안을 작성하세요.
# - Seaborn을 활용하세요.
# - 필요하다면 value_counts()를 사용하여 정확한 숫자를 확인하세요.
# - 출력된 그래프와 통계를 보고 해석한 것으로 옳은 선택지를 아래에서 골라 "답안04" 변수에 저장하세요(예: 답안04=1)
#     1. France는 4000명 이상이 은행을 유지하고 있다.
#     2. 모든 지역에서 은행을 이탈한 고객은 1000명 이하이다.
#     3. Spain이 은행 유지 고객과 은행 이탈 고객의 차가 가장 적다.
# ---

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# ### 5. 계좌 잔액(Balance)의 분포를 확인해 보려고 합니다.
# ---
# 성별(Gender)에 따른 계좌 잔액(Balance) 분포를 히스토그램(histplot) 으로 시각화하세요.
# - 대상 데이터프레임: df
# ---

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# <br>

# %% [markdown]
# ### 6. 수치형 변수들의 상관관계를 확인하세요.
# ---
# 다음 가이드를 따라 그래프를 시각화하세요.
# - 대상 데이터프레임: df
# - seaborn을 사용하세요
#     - 그래프 안에 상관관계 수치를 표시하세요.
# - 고객 이탈 여부(Exited)와 강한 양의 상관관계를 가지는 컬럼을 "답안06"변수에 작성하세요. (예: 답안06="컬럼명")
# ---

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# <br>

# %% [markdown]
# ### 7. 고객 이탈 여부(Exited) 별 보유한 은행 상품 수(NumOfProducts)에 대해 추정 연봉(EstimatedSalary)의 평균을 구하세요.
# ---
# - groupby를 사용하여 제시한 조건에 대한 통계를 구하세요.
# - 출력된 결과를 보고 평균 추정 연봉(EstimatedSalary)이 가장 높은 이탈 고객 그룹의 은행 상품 보유 수(NumOfProducts)를 "답안07" 변수에 저장하세요.(예: 답안07=1)
# ---

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# <br>

# %% [markdown]
# ### 8. 모델링 성능을 제대로 얻기 위해서 필요없는 컬럼을 제거해야 합니다.
# ---
# 아래 가이드를 따라 결측치를 처리 하세요.
# - 대상 데이터프레임: df
# - 'RowNumber', 'CustomerId', 'Surname' 컬럼을 제거하세요.
# - 전처리 반영된 결과를 새로운 데이터프레임 변수명 df_del 에 저장하세요.
# ---

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# <br>

# %% [markdown]
# ### 9. 모델링 성능을 제대로 얻기 위해서 결측치 처리는 필수입니다.
# ---
#  아래 가이드를 따라 결측치를 처리 하세요.
# - 대상 데이터프레임: df_del
#     - 결측치를 확인하는 코드를 작성하세요.
#     - 다음 가이드에 따라 결측치를 대체하세요.
#         - 범주형 컬럼은 최빈값으로 대체하세요.
#         - 수치형 컬럼은 중앙값으로 대체하세요.
#     - 전처리 반영된 결과를 새로운 데이터프레임 변수명 df_na 에 저장하세요.
# ---

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# <br>

# %% [markdown]
# ### 10. 원-핫 인코딩(One-hot encoding)은 범주형 변수를 수치형 변수로 변환하기 위하여 사용하는 방법입니다.
# ---
# 아래 조건에 해당하는 컬럼 데이터에 원-핫 인코딩을 적용하세요.
# - 대상 데이터프레임: df_na
# - 원-핫 인코딩 대상: ["Gender", "Geography", "NumOfProducts", "HasCrCard"]
# - 활용 함수: Pandas의 get_dummies
# - 원-핫 인코딩 수행 시, 첫 번째 범주를 제거하고 float 타입으로 저장하세요.
# - 해당 전처리가 반영된 결과를 데이터프레임 변수 df_enc 에 저장해 주세요.
# ----

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# <br>

# %% [markdown]
# ### 11. 훈련과 검증 각각에 사용할 데이터셋을 분리하려고 합니다.
# ---
# "Exited" 컬럼을 y로, 나머지 컬럼을 X로 할당한 후, 훈련데이터셋과 검증데이터셋으로 분리하세요.
#
#  - 대상 데이터프레임: df_enc
#  - 훈련과 검증 데이터셋 분리
#      - 훈련 데이터셋 label: y_train, 훈련 데이터셋 Feature: X_train
#      - 검증 데이터셋 label: y_valid, 검증 데이터셋 Feature: X_valid
#      - 훈련 데이터셋과 검증데이터셋의 비율은 80:20
#      - random_state: 42
#      - Scikit-learn의 train_test_split 함수를 활용하세요
# ---

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# <br>

# %% [markdown]
# ## 12. 현재의 데이터셋은 머신러닝에 바로 사용할 수 없는 형태입니다.
# ---
# 특정 스케일링 클래스를 사용하지 않고, 하단의 수식을 활용하여 데이터를 스케일링하세요.
# - X_train을 기준으로 평균과 표준편차를 계산하세요.
# - 스케일링이 적용된 훈련데이터셋은 x_train 변수로, 검증데이터셋은 x_valid 변수에 할당하세요.
#
# ---

# %% [markdown]
# ![image.png](attachment:6070a381-5b2f-4051-aea6-3b9b73808e85.png)

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# <br>

# %% [markdown]
# ### 13. 고객 이탈 여부를 예측하는 머신러닝 모델을 만들려고 합니다.
# ---
# 의사결정나무(decision tree)는 여러가지 규칙을 순차적으로 적용하면서 독립변수공간을 분할하는 모형으로 분류와 회귀분석에 모두 사용될 수 있습니다.
# 아래 가이드에 따라 의사결정나무(decision tree) 모델을 만들고 학습을 진행하세요.
#
# - 의사결정나무(decision tree)
#      - 트리의 최대 깊이 : 5로 설정
#      - 노드를 분할하기 위한 최소한의 샘플 데이터수(min_samples_split) : 3로 설정
#      - random_state : 50로 설정
#      - 의사결정나무(decision tree) 모델을 dt 변수에 저장해 주세요.
#
# - 위의 모델에 대해 fit을 활용해 모델을 학습해 주세요. 학습 시 훈련데이터 셋을 활용해 주세요.
# ---

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# <br>

# %% [markdown]
# ### 14. 위 의사결정나무(decision tree) 모델의 성능을 평가하려고 합니다.
# ---
# 아래 가이드에 따라 예측 결과의 성능을 구하고 평가하세요.
# - 성능 평가는 검증 데이터셋을 활용하세요.
# - 13번 문제에서 만든 의사결정나무(decision tree) 모델로 y값을 예측(predict)하여 y_pred_dt에 저장하세요.
# - 검증 정답(y_valid)과 예측값(y_pred_dt)을 활용하여 sklearn.metrics의 classification_report를 출력하세요.
# - 가중 평균의 f1-score를 "답안14"변수에 소수점 둘째자리까지 작성하세요.
# ---

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# <br>

# %% [markdown]
# 다음 문항을 풀기 전에 아래의 코드를 실행하세요.

# %%
import random
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import to_categorical

random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)
tf.keras.utils.set_random_seed(42)
# print(tf.config.list_physical_devices('CPU'))

# %% [markdown]
# <br>

# %% [markdown]
# ### 15. 고객 이탈 여부를 예측하는 딥러닝 모델을 만들려고 합니다.
# ---
# 아래 가이드에 따라 모델링하고 학습을 진행하세요.
# - Tensorflow framework를 사용하여 딥러닝 모델을 만드세요.
# - 아래의 설계된 모델을 구현하세요.
# - 손실함수는 'binary_crossentropy'를 사용하고, 손실함수를 최적화하기 위한 알고리즘은 'adam'을 사용하세요.
# - 각 에포크마다 검증데이터셋을 'acc'로 평가하세요.
# - 하이퍼파라미터 epochs : 30, batch_size : 32 로 설정해 주세요.
# - 각 에포크마다 loss와 metrics 평가하기 위한 데이터로 x_valid, y_valid 사용하세요.
# - EarlyStopping을 사용하여 val_loss를 보고 5회의 대기 후 성능이 향상되지 않으면 종료하며, 가장 낮은 검증 손실을 낸 모델 파라미터로 복구하세요.
# - ModelCheckpoint를 활용하여 동일 폴더에 'best_model.h5'라는 이름의 가장 좋은 성능의 모델만 저장하세요.
# - 학습정보는 history 변수에 저장해 주세요.
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 다음 문항을 풀기 전에 아래의 코드를 실행하세요.
y_train = to_categorical(y_train, num_classes=2)
y_valid = to_categorical(y_valid, num_classes=2)

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# <br>

# %% [markdown]
# ### 16. 15번 딥러닝 모델의 성능을 평가하려고 합니다.
# ---
# Matplotlib 라이브러리를 활용해서 학습 acc와 검증 acc를 그래프로 표시하세요.
# - 1개의 그래프에 학습 acc과 검증 acc 2가지를 모두 표시하세요.
# - 위 2가지 각각의 범례를 'acc', 'val_acc'로 표시하세요.
# - 그래프의 타이틀은 'Model Accuracy'로 표시하세요.
# - X축에는 'Epoch'라고 표시하고 Y축에는 'Accuracy'라고 표시하세요.
# ---

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# <br>

# %% [markdown]
# ### 17. 15번에서 저장한 딥러닝 모델을 불러와서 주어진 데이터로 시뮬레이션을 하려합니다.
# ---
# 다음 가이드를 따라 시뮬레이션을 진행하세요.
# - tensorflow.keras.models의 load_model을 사용하여 모델을 불러옵니다.
# - 주어진 시뮬레이션 데이터에 대해 예측결과를 구하고 고객이 이탈하는 경우 Y, 이탈하지 않는 경우  N을 답안17 변수에 저장하세요.(예: 답안17='Y')
# ---

# %%
simul = np.array([[-0.7227391446644401, 0.19985353715359516, 0.34504653074020003, -0.09210001624683391, 0.9732940159478687, 1.3515048050562315, 0.9131904722488554, 1.7256152737786, -0.5763519926952669, 1.0806829680839476, -0.16537793670681789, -0.07520713069821101, -1.540254750506717]])

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# <br>

# %% [markdown]
# 모든 문제를 다 푸셨습니다. 고생하셨습니다.
